# %% [markdown]
# ## Image Representation

# %%
import numpy as np
import matplotlib.pyplot as plt

# %config InlineBackend.figure_formats = 'retina'

# %%
image = np.array([[0, 255, 0], [50, 200, 50], [110, 127, 140]])

plt.imshow(image, cmap="gray")
